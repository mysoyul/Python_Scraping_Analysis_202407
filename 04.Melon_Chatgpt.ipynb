# %% [markdown]
# * https://www.melon.com/chart/index.htm
# *
# Melon 100 chart 에서 100곡의 노래 정보를 웹스크래핑 하는 source code를 작성해 주세요

# %%
import requests
from bs4 import BeautifulSoup

# Melon 100 차트 URL
url = 'https://www.melon.com/chart/index.htm'

# 요청 헤더 설정 (Melon 사이트가 봇 접근을 막기 위해 설정)
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36',
    'Referer': 'https://www.melon.com/index.htm'
}

# 페이지 요청 및 파싱
response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.text, 'html.parser')

# 곡 정보가 담긴 리스트 가져오기
songs = soup.select('tr[data-song-no]')

# 각 곡의 정보 추출
song_data = []
for song in songs:
    song_no = song['data-song-no']
    title = song.select_one('div.ellipsis.rank01 > span > a').text
    artist = song.select_one('div.ellipsis.rank02 > a').text
    album = song.select_one('div.ellipsis.rank03 > a').text
    rank = song.select_one('span.rank').text

    song_data.append({
        'rank': rank,
        'song_no': song_no,
        'title': title,
        'artist': artist,
        'album': album
    })

# 결과 출력
for data in song_data:
    print(f"Rank: {data['rank']} | Title: {data['title']} | Artist: {data['artist']} | Album: {data['album']} | Song No: {data['song_no']}")

# 파일로 저장 (선택사항)
import csv

with open('melon_top_100.csv', 'w', newline='', encoding='utf-8') as file:
    writer = csv.DictWriter(file, fieldnames=['rank', 'song_no', 'title', 'artist', 'album'])
    writer.writeheader()
    writer.writerows(song_data)
# Out:
# Rank: 1 | Title: Supernova | Artist: aespa | Album: Armageddon - The 1st Album | Song No: 37524037
# Rank: 2 | Title: How Sweet | Artist: NewJeans | Album: How Sweet | Song No: 37563682
# Rank: 3 | Title: Small girl (feat. 도경수(D.O.)) | Artist: 이영지 | Album: 16 Fantasy | Song No: 37657039
# Rank: 4 | Title: Supernatural | Artist: NewJeans | Album: Supernatural | Song No: 37659322
# Rank: 5 | Title: Sticky | Artist: KISS OF LIFE | Album: Sticky | Song No: 37693124
# Rank: 6 | Title: 소나기 | Artist: 이클립스 (ECLIPSE) | Album: 선재 업고 튀어 OST Part 1 | Song No: 37390939
# Rank: 7 | Title: 클락션 (Klaxon) | Artist: (여자)아이들 | Album: I SWAY | Song No: 37737619
# Rank: 8 | Title: 사랑은 늘 도망가 | Artist: 임영웅 | Album: 신사와 아가씨 OST Part.2 | Song No: 34061322
# Rank: 9 | Title: 고민중독 | Artist: QWER | Album: 1st Mini Album 'MANITO' | Song No: 37373234
# Rank: 10 | Title: Bubble Gum | Artist: NewJeans | Album: How Sweet | Song No: 37464459
# Rank: 11 | Title: Armageddon | Artist: aespa | Album: Armageddon - The 1st Album | Song No: 37524038
# Rank: 12 | Title: 온기 | Artist: 임영웅 | Album: 온기 | Song No: 37491072
# Rank: 13 | Title: Home | Artist: 임영웅 | Album: 온기 | Song No: 37491071
# Rank: 14 | Title: 한 페이지가 될 수 있게 | Artist: DAY6 (데이식스) | Album: The Book of Us : Gravity | Song No: 31927275
# Rank: 15 | Title: 우리들의 블루스 | Artist: 임영웅 | Album: IM HERO | Song No: 34908740
어떻게 이별까지 사랑하겠어, 널 사랑하는 거지 | Artist: AKMU (악뮤) | Album: 항해 | Song No: 32061975
# Rank: 90 | Title: LOVE DIVE | Artist: IVE (아이브) | Album: LOVE DIVE | Song No: 34847378
# Rank: 91 | Title: 취중고백 | Artist: 김민석 | Album: 취중고백 | Song No: 34431086
# Rank: 92 | Title: Impossible | Artist: RIIZE | Album: RIIZING - The 1st Mini Album | Song No: 37431365
# Rank: 93 | Title: I Don't Think That I Like Her | Artist: Charlie Puth | Album: CHARLIE | Song No: 35640751
# Rank: 94 | Title: MANIAC | Artist: VIVIZ (비비지) | Album: The 4th Mini Album 'VERSUS' | Song No: 36930793
# Rank: 95 | Title: Love Lee | Artist: AKMU (악뮤) | Album: Love Lee | Song No: 36713849
# Rank: 96 | Title: 봄눈 | Artist: 10CM | Album: 선재 업고 튀어 OST Part 8 | Song No: 37526257
# Rank: 97 | Title: 꿈 | Artist: 태연 (TAEYEON) | Album: 웰컴투 삼달리 OST Part.3 | Song No: 37064763
# Rank: 98 | Title: Siren | Artist: RIIZE | Album: RIIZING - The 1st Mini Album | Song No: 37378932
# Rank: 99 | Title: Lucky Girl Syndrome | Artist: 아일릿(ILLIT) | Album: SUPER REAL ME | Song No: 37347913
# Rank: 100 | Title: Smeraldo Garden Marching Band (feat. 로꼬) | Artist: 지민 | Album: MUSE | Song No: 37691812

# %% [markdown]
# * https://www.melon.com/chart/index.htm
# * Melon 100 chart 에서 100곡의 노래 정보를 웹스크래핑 하는 source code를 작성해 주세요.
# * 추출할 항목은 노래의 제목, 가수이름, 앨범, 앨범발매일, 장르, 좋아요건수, 가사 입니다.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# Melon 100 차트 URL
base_url = 'https://www.melon.com/chart/index.htm'
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36',
    'Referer': 'https://www.melon.com/index.htm'
}

# 페이지 요청 및 파싱
response = requests.get(base_url, headers=headers)
soup = BeautifulSoup(response.text, 'html.parser')

# 곡 정보가 담긴 리스트 가져오기
songs = soup.select('tr[data-song-no]')

# 각 곡의 정보 추출
song_data = []
for song in songs:
    print(song)
    song_id = song['data-song-no']
    title = song.select_one('div.ellipsis.rank01 > span > a').text
    artist = song.select_one('div.ellipsis.rank02 > a').text
    album = song.select_one('div.ellipsis.rank03 > a').text

    # 곡의 상세 정보 페이지 요청 및 파싱
    detail_url = f'https://www.melon.com/song/detail.htm?songId={song_id}'
    detail_response = requests.get(detail_url, headers=headers)
    detail_soup = BeautifulSoup(detail_response.text, 'html.parser')

    release_date = detail_soup.select_one('dl.list > dd:nth-of-type(2)').text
    genre = detail_soup.select_one('dl.list > dd:nth-of-type(3)').text
    likes = detail_soup.select_one('span.cnt').text.strip('총건수').replace(',', '').strip()

    lyrics = detail_soup.select_one('div.lyric')
    if lyrics:
        lyrics = lyrics.text.strip()
    else:
        lyrics = ''

    song_data.append({
        'title': title,
        'artist': artist,
        'album': album,
        'release_date': release_date,
        'genre': genre,
        'likes': likes,
        'lyrics': lyrics
    })

# Pandas DataFrame으로 변환
df = pd.DataFrame(song_data)

# 결과를 CSV 파일로 저장
df.to_csv('melon_top_100.csv', index=False, encoding='utf-8-sig')

# 결과 출력 (선택사항)
print(df)
# Out:
# <tr class="lst50" data-song-no="37524037" id="lst50">
# <td><div class="wrap t_right"><input class="input_check" name="input_check" title="Supernova 곡 선택" type="checkbox" value="37524037"/></div></td>
# <td><div class="wrap t_center"><span class="rank">1</span><span class="none">위</span></div></td>
# <!-- 차트순위 추가 -->
# <td><div class="wrap">
# <span class="rank_wrap" title="순위 동일">
# <span class="bullet_icons rank_static"><span class="none">순위 동일</span></span>
# <span class="none">0</span>
# </span>
# </div></td>
# <td><div class="wrap">
# <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('11487023');" title="Armageddon - The 1st Album">
# <img alt="Armageddon - The 1st Album - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="https://cdnimg.melon.co.kr/cm2/album/images/114/87/023/11487023_20240527154018_500.jpg/melon/resize/120/quality/80/optimize" width="60">
# <span class="bg_album_frame"></span>
# </img></a>
# </div></td>
# <td><div class="wrap">
# <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('37524037');" title="Supernova 곡정보"><span class="none">곡정보</span></a>
# </div></td>
# <td><div class="wrap">
# <div class="wrap_song_info">
# <div class="ellipsis rank01"><span>
# <a href="javascript:melon.play.playSong('1000002721',37524037);" title="Supernova 재생">Supernova</a>
# </span></div><br/>
# <div class="ellipsis rank02">
# <a href="javascript:melon.link.goArtistDetail('2899555');" title="aespa - 페이지 이동">aespa</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('2899555');" title="aespa - 페이지 이동">aespa</a></span>
# </div>
# </div>
# </div></td>
# <td><div class="wrap">
# <div class="wrap_song_info">
# <div class="ellipsis rank03">
# <a href="javascript:melon.link.goAlbumDetail('11487023');" title="Armageddon - The 1st Album - 페이지 이동">Armageddon - The 1st Album</a>
# </div>
# </div>
# </div></td>
# <td><div class="wrap">
# <button class="button_etc like" data-song-menuid="1000002721" data-song-no="37524037" title="Supernova 좋아요" type="button">
# <span class="odd_span">좋아요</span>
# <span class="cnt">
# <span class="none">총건수</span>
# 												0
# 											</span>
# </button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons play" onclick="melon.play.playSong('1000002721',37524037);" title="듣기" type="button"><span class="none">듣기</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons scrap" onclick="melon.play.addPlayList('37524037');" title="담기" type="button"><span class="none">담기</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons download" onclick="melon.buy.goBuyProduct('frm', '37524037', '3C0001', '','0', '1000002721');" title="다운로드" type="button"><span class="none">다운로드</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons video" onclick="melon.link.goMvDetail('1000002721', '37524037','song');" title="뮤직비디오" type="button"><span class="none">뮤직비디오</span></button>
# </div></td>
# </tr>
# <tr class="lst50" data-song-no="37563682" id="lst50">
# <td><div class="wrap t_right"><input class="input_check" name="input_check" title="How Sweet 곡 선택" type="checkbox" value="37563682"/></div></td>
# <td><div class="wrap t_center"><span class="rank">2</span><span class="none">위</span></div></td>
# <!-- 차트순위 추가 -->
# <td><div class="wrap">
# <span class="rank_wrap" title="순위 동일">
# <span class="bullet_icons rank_static"><span class="none">순위 동일</span></span>
# <span class="none">0</span>
# </span>
# </div></td>
# <td><div class="wrap">
# <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('11475749');" title="How Sweet">
# <img alt="How Sweet - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="https://cdnimg.melon.co.kr/cm2/album/images/114/75/749/11475749_20240524105642_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
# <span class="bg_album_frame"></span>
# </a>
# </div></td>
# <td><div class="wrap">
# <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('37563682');" title="How Sweet 곡정보"><span class="none">곡정보</span></a>
# </div></td>
# <td><div class="wrap">
# <div class="wrap_song_info">
# <div class="ellipsis rank01"><span>
# <a href="javascript:melon.play.playSong('1000002721',37563682);" title="How Sweet 재생">How Sweet</a>
# </span></div><br/>
# <div class="ellipsis rank02">
# <a href="javascript:melon.link.goArtistDetail('3114174');" title="NewJeans - 페이지 이동">NewJeans</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('3114174');" title="NewJeans - 페이지 이동">NewJeans</a></span>
# </div>
# </div>
# </div></td>
# <td><div class="wrap">
# <div class="wrap_song_info">
# <div class="ellipsis rank03">
# <a href="javascript:melon.link.goAlbumDetail('11475749');" title="How Sweet - 페이지 이동">How Sweet</a>
# </div>
# </div>
# </div></td>
# <td><div class="wrap">
# <button class="button_etc like" data-song-menuid="1000002721" data-song-no="37563682" title="How Sweet 좋아요" type="button">
# <span class="odd_span">좋아요</span>
# <span class="cnt">
# <span class="none">총건수</span>
# 												0
# 											</span>
# </button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons play" onclick="melon.play.playSong('1000002721',37563682);" title="듣기" type="button"><span class="none">듣기</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons scrap" onclick="melon.play.addPlayList('37563682');" title="담기" type="button"><span class="none">담기</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons download" onclick="melon.buy.goBuyProduct('frm', '37563682', '3C0001', '','0', '1000002721');" title="다운로드" type="button"><span class="none">다운로드</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons video" onclick="melon.link.goMvDetail('1000002721', '37563682','song');" title="뮤직비디오" type="button"><span class="none">뮤직비디오</span></button>
# </div></td>
# </tr>
# <tr class="lst50" data-song-no="37657039" id="lst50">
# <td><div class="wrap t_right"><input class="input_check" name="input_check" title="Small girl (feat. 도경수(D.O.)) 곡 선택" type="checkbox" value="37657039"/></div></td>
# <td><div class="wrap t_center"><span class="rank">3</span><span class="none">위</span></div></td>
# <!-- 차트순위 추가 -->
# <td><div class="wrap">
# <span class="rank_wrap" title="순위 동일">
# <span class="bullet_icons rank_static"><span class="none">순위 동일</span></span>
# <span class="none">0</span>
# </span>
# </div></td>
# <td><div class="wrap">
# <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('11517951');" title="16 Fantasy">
# <img alt="16 Fantasy - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="https://cdnimg.melon.co.kr/cm2/album/images/115/17/951/11517951_20240620173412_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
# <span class="bg_album_frame"></span>
# </a>
# </div></td>
# <td><div class="wrap">
# <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('37657039');" title="Small girl (feat. 도경수(D.O.)) 곡정보"><span class="none">곡정보</span></a>
# </div></td>
# <td><div class="wrap">
# <div class="wrap_song_info">
# <div class="ellipsis rank01"><span>
# <a href="javascript:melon.play.playSong('1000002721',37657039);" title="Small girl (feat. 도경수(D.O.)) 재생">Small girl (feat. 도경수(D.O.))</a>
# </span></div><br/>
# <div class="ellipsis rank02">
# <a href="javascript:melon.link.goArtistDetail('2636153');" title="이영지 - 페이지 이동">이영지</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('2636153');" title="이영지 - 페이지 이동">이영지</a></span>
# </div>
# </div>
# </div></td>
# <td><div class="wrap">
# <div class="wrap_song_info">
# <div class="ellipsis rank03">
# <a href="javascript:melon.link.goAlbumDetail('11517951');" title="16 Fantasy - 페이지 이동">16 Fantasy</a>
# </div>
# </div>
# </div></td>
# <td><div class="wrap">
# <button class="button_etc like" data-song-menuid="1000002721" data-song-no="37657039" title="Small girl (feat. 도경수(D.O.)) 좋아요" type="button">
# <span class="odd_span">좋아요</span>
# <span class="cnt">
# <span class="none">총건수</span>
# 												0
# 											</span>
# </button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons play" onclick="melon.play.playSong('1000002721',37657039);" title="듣기" type="button"><span class="none">듣기</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons scrap" onclick="melon.play.addPlayList('37657039');" title="담기" type="button"><span class="none">담기</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons download" onclick="melon.buy.goBuyProduct('frm', '37657039', '3C0001', '','0', '1000002721');" title="다운로드" type="button"><span class="none">다운로드</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons video disabled" disabled="disabled" onclick="melon.link.goMvDetail('1000002721', '37657039','song');" title="뮤직비디오" type="button"><span class="none">뮤직비디오</span></button>
# </div></td>
# </tr>
# <tr class="lst50" data-song-no="37737619" id="lst50">
# <td><div class="wrap t_right"><input class="input_check" name="input_check" title="클락션 (Klaxon) 곡 선택" type="checkbox" value="37737619"/></div></td>
# <td><div class="wrap t_center"><span class="rank">4</span><span class="none">위</span></div></td>
# <!-- 차트순위 추가 -->
# <td><div class="wrap">
# <span class="rank_wrap" title="순위 동일">
# <span class="bullet_icons rank_static"><span class="none">순위 동일</span></span>
# <span class="none">0</span>
# </span>
# </div></td>
# <td><div class="wrap">
# <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('11533515');" title="I SWAY">
# <img alt="I SWAY - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="https://cdnimg.melon.co.kr/cm2/album/images/115/33/515/11533515_20240708112323_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
# <span class="bg_album_frame"></span>
# </a>
# </div></td>
# <td><div class="wrap">
# <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('37737619');" title="클락션 (Klaxon) 곡정보"><span class="none">곡정보</span></a>
# </div></td>
# <td><div class="wrap">
# <div class="wrap_song_info">
# <div class="ellipsis rank01"><span>
# <a href="javascript:melon.play.playSong('1000002721',37737619);" title="클락션 (Klaxon) 재생">클락션 (Klaxon)</a>
# </span></div><br/>
# <div class="ellipsis rank02">
# <a href="javascript:melon.link.goArtistDetail('2137482');" title="(여자)아이들 - 페이지 이동">(여자)아이들</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('2137482');" title="(여자)아이들 - 페이지 이동">(여자)아이들</a></span>
# </div>
# </div>
# </div></td>
# <td><div class="wrap">
# <div class="wrap_song_info">
# <div class="ellipsis rank03">
# <a href="javascript:melon.link.goAlbumDetail('11533515');" title="I SWAY - 페이지 이동">I SWAY</a>
# </div>
# </div>
# </div></td>
# <td><div class="wrap">
# <button class="button_etc like" data-song-menuid="1000002721" data-song-no="37737619" title="클락션 (Klaxon) 좋아요" type="button">
# <span class="odd_span">좋아요</span>
# <span class="cnt">
# <span class="none">총건수</span>
# 												0
# 											</span>
# </button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons play" onclick="melon.play.playSong('1000002721',37737619);" title="듣기" type="button"><span class="none">듣기</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons scrap" onclick="melon.play.addPlayList('37737619');" title="담기" type="button"><span class="none">담기</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons download" onclick="melon.buy.goBuyProduct('frm', '37737619', '3C0001', '','0', '1000002721');" title="다운로드" type="button"><span class="none">다운로드</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons video" onclick="melon.link.goMvDetail('1000002721', '37737619','song');" title="뮤직비디오" type="button"><span class="none">뮤직비디오</span></button>
# </div></td>
# </tr>
# <tr class="lst50" data-song-no="37659322" id="lst50">
# <td><div class="wrap t_right"><input class="input_check" name="input_check" title="Supernatural 곡 선택" type="checkbox" value="37659322"/></div></td>
# <td><div class="wrap t_center"><span class="rank">5</span><span class="none">위</span></div></td>
# <!-- 차트순위 추가 -->
# <td><div class="wrap">
# <span class="rank_wrap" title="순위 동일">
# <span class="bullet_icons rank_static"><span class="none">순위 동일</span></span>
# <span class="none">0</span>
# </span>
# </div></td>
# <td><div class="wrap">
# <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('11514014');" title="Supernatural">
# <img alt="Supernatural - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="https://cdnimg.melon.co.kr/cm2/album/images/115/14/014/11514014_20240621110830_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
# <span class="bg_album_frame"></span>
# </a>
# </div></td>
# <td><div class="wrap">
# <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('37659322');" title="Supernatural 곡정보"><span class="none">곡정보</span></a>
# </div></td>
# <td><div class="wrap">
# <div class="wrap_song_info">
# <div class="ellipsis rank01"><span>
# <a href="javascript:melon.play.playSong('1000002721',37659322);" title="Supernatural 재생">Supernatural</a>
# </span></div><br/>
# <div class="ellipsis rank02">
# <a href="javascript:melon.link.goArtistDetail('3114174');" title="NewJeans - 페이지 이동">NewJeans</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('3114174');" title="NewJeans - 페이지 이동">NewJeans</a></span>
# </div>
# </div>
# </div></td>
# <td><div class="wrap">
# <div class="wrap_song_info">
# <div class="ellipsis rank03">
# <a href="javascript:melon.link.goAlbumDetail('11514014');" title="Supernatural - 페이지 이동">Supernatural</a>
# </div>
# </div>
# </div></td>
# <td><div class="wrap">
# <button class="button_etc like" data-song-menuid="1000002721" data-song-no="37659322" title="Supernatural 좋아요" type="button">
# <span class="odd_span">좋아요</span>
# <span class="cnt">
# <span class="none">총건수</span>
# 												0
# 											</span>
# </button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons play" onclick="melon.play.playSong('1000002721',37659322);" title="듣기" type="button"><span class="none">듣기</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons scrap" onclick="melon.play.addPlayList('37659322');" title="담기" type="button"><span class="none">담기</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons download" onclick="melon.buy.goBuyProduct('frm', '37659322', '3C0001', '','0', '1000002721');" title="다운로드" type="button"><span class="none">다운로드</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons video" onclick="melon.link.goMvDetail('1000002721', '37659322','song');" title="뮤직비디오" type="button"><span class="none">뮤직비디오</span></button>
# </div></td>
# </tr>
# <tr class="lst50" data-song-no="37693124" id="lst50">
# <td><div class="wrap t_right"><input class="input_check" name="input_check" title="Sticky 곡 선택" type="checkbox" value="37693124"/></div></td>
# <td><div class="wrap t_center"><span class="rank">6</span><span class="none">위</span></div></td>
# <!-- 차트순위 추가 -->
# <td><div class="wrap">
# <span class="rank_wrap" title="순위 동일">
# <span class="bullet_icons rank_static"><span class="none">순위 동일</span></span>
# <span class="none">0</span>
# </span>
# </div></td>
# <td><div class="wrap">
# <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('11525661');" title="Sticky">
# <img alt="Sticky - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="https://cdnimg.melon.co.kr/cm2/album/images/115/25/661/11525661_20240628155508_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
# <span class="bg_album_frame"></span>
# </a>
# </div></td>
# <td><div class="wrap">
# <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('37693124');" title="Sticky 곡정보"><span class="none">곡정보</span></a>
# </div></td>
# <td><div class="wrap">
# <div class="wrap_song_info">
# <div class="ellipsis rank01"><span>
# <a href="javascript:melon.play.playSong('1000002721',37693124);" title="Sticky 재생">Sticky</a>
# </span></div><br/>
# <div class="ellipsis rank02">
# <a href="javascript:melon.link.goArtistDetail('3465800');" title="KISS OF LIFE - 페이지 이동">KISS OF LIFE</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('3465800');" title="KISS OF LIFE - 페이지 이동">KISS OF LIFE</a></span>
# </div>
# </div>
# </div></td>
# <td><div class="wrap">
# <div class="wrap_song_info">
# <div class="ellipsis rank03">
# <a href="javascript:melon.link.goAlbumDetail('11525661');" title="Sticky - 페이지 이동">Sticky</a>
# </div>
# </div>
# </div></td>
# <td><div class="wrap">
# <button class="button_etc like" data-song-menuid="1000002721" data-song-no="37693124" title="Sticky 좋아요" type="button">
# <span class="odd_span">좋아요</span>
# <span class="cnt">
# <span class="none">총건수</span>
# 												0
# 											</span>
# </button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons play" onclick="melon.play.playSong('1000002721',37693124);" title="듣기" type="button"><span class="none">듣기</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons scrap" onclick="melon.play.addPlayList('37693124');" title="담기" type="button"><span class="none">담기</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons download" onclick="melon.buy.goBuyProduct('frm', '37693124', '3C0001', '','0', '1000002721');" title="다운로드" type="button"><span class="none">다운로드</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons video" onclick="melon.link.goMvDetail('1000002721', '37693124','song');" title="뮤직비디오" type="button"><span class="none">뮤직비디오</span></button>
# </div></td>
# </tr>
# <tr class="lst50" data-song-no="37390939" id="lst50">
# <td><div class="wrap t_right"><input class="input_check" name="input_check" title="소나기 곡 선택" type="checkbox" value="37390939"/></div></td>
# <td><div class="wrap t_center"><span class="rank">7</span><span class="none">위</span></div></td>
# <!-- 차트순위 추가 -->
# <td><div class="wrap">
# <span class="rank_wrap" title="순위 동일">
# <span class="bullet_icons rank_static"><span class="none">순위 동일</span></span>
# <span class="none">0</span>
# </span>
# </div></td>
# <td><div class="wrap">
# <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('11459325');" title="선재 업고 튀어 OST Part 1">
# <img alt="선재 업고 튀어 OST Part 1 - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="https://cdnimg.melon.co.kr/cm2/album/images/114/59/325/11459325_20240405171054_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
# <span class="bg_album_frame"></span>
# </a>
# </div></td>
# <td><div class="wrap">
# <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('37390939');" title="소나기 곡정보"><span class="none">곡정보</span></a>
# </div></td>
# <td><div class="wrap">
# <div class="wrap_song_info">
# <div class="ellipsis rank01"><span>
# <a href="javascript:melon.play.playSong('1000002721',37390939);" title="소나기 재생">소나기</a>
# </span></div><br/>
# <div class="ellipsis rank02">
# <a href="javascript:melon.link.goArtistDetail('3752136');" title="이클립스 (ECLIPSE) - 페이지 이동">이클립스 (ECLIPSE)</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('3752136');" title="이클립스 (ECLIPSE) - 페이지 이동">이클립스 (ECLIPSE)</a></span>
# </div>
# </div>
# </div></td>
# <td><div class="wrap">
# <div class="wrap_song_info">
# <div class="ellipsis rank03">
# <a href="javascript:melon.link.goAlbumDetail('11459325');" title="선재 업고 튀어 OST Part 1 - 페이지 이동">선재 업고 튀어 OST Part 1</a>
# </div>
# </div>
# </div></td>
# <td><div class="wrap">
# <button class="button_etc like" data-song-menuid="1000002721" data-song-no="37390939" title="소나기 좋아요" type="button">
# <span class="odd_span">좋아요</span>
# <span class="cnt">
# <span class="none">총건수</span>
# 												0
# 											</span>
# </button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons play" onclick="melon.play.playSong('1000002721',37390939);" title="듣기" type="button"><span class="none">듣기</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons scrap" onclick="melon.play.addPlayList('37390939');" title="담기" type="button"><span class="none">담기</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons download" onclick="melon.buy.goBuyProduct('frm', '37390939', '3C0001', '','0', '1000002721');" title="다운로드" type="button"><span class="none">다운로드</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons video disabled" disabled="disabled" onclick="melon.link.goMvDetail('1000002721', '37390939','song');" title="뮤직비디오" type="button"><span class="none">뮤직비디오</span></button>
# </div></td>
# </tr>
# <tr class="lst50" data-song-no="37373234" id="lst50">
# <td><div class="wrap t_right"><input class="input_check" name="input_check" title="고민중독 곡 선택" type="checkbox" value="37373234"/></div></td>
# <td><div class="wrap t_center"><span class="rank">8</span><span class="none">위</span></div></td>
# <!-- 차트순위 추가 -->
# <td><div class="wrap">
# <span class="rank_wrap" title="순위 동일">
# <span class="bullet_icons rank_static"><span class="none">순위 동일</span></span>
# <span class="none">0</span>
# </span>
# </div></td>
# <td><div class="wrap">
# <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('11454681');" title="1st Mini Album 'MANITO'">
# <img alt="1st Mini Album 'MANITO' - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="https://cdnimg.melon.co.kr/cm2/album/images/114/54/681/11454681_20240328174504_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
# <span class="bg_album_frame"></span>
# </a>
# </div></td>
# <td><div class="wrap">
# <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('37373234');" title="고민중독 곡정보"><span class="none">곡정보</span></a>
# </div></td>
# <td><div class="wrap">
# <div class="wrap_song_info">
# <div class="ellipsis rank01"><span>
# <a href="javascript:melon.play.playSong('1000002721',37373234);" title="고민중독 재생">고민중독</a>
# </span></div><br/>
# <div class="ellipsis rank02">
# <a href="javascript:melon.link.goArtistDetail('3610529');" title="QWER - 페이지 이동">QWER</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('3610529');" title="QWER - 페이지 이동">QWER</a></span>
# </div>
# </div>
# </div></td>
# <td><div class="wrap">
# <div class="wrap_song_info">
# <div class="ellipsis rank03">
# <a href="javascript:melon.link.goAlbumDetail('11454681');" title="1st Mini Album 'MANITO' - 페이지 이동">1st Mini Album 'MANITO'</a>
# </div>
# </div>
# </div></td>
# <td><div class="wrap">
# <button class="button_etc like" data-song-menuid="1000002721" data-song-no="37373234" title="고민중독 좋아요" type="button">
# <span class="odd_span">좋아요</span>
# <span class="cnt">
# <span class="none">총건수</span>
# 												0
# 											</span>
# </button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons play" onclick="melon.play.playSong('1000002721',37373234);" title="듣기" type="button"><span class="none">듣기</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons scrap" onclick="melon.play.addPlayList('37373234');" title="담기" type="button"><span class="none">담기</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons download" onclick="melon.buy.goBuyProduct('frm', '37373234', '3C0001', '','0', '1000002721');" title="다운로드" type="button"><span class="none">다운로드</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons video" onclick="melon.link.goMvDetail('1000002721', '37373234','song');" title="뮤직비디오" type="button"><span class="none">뮤직비디오</span></button>
# </div></td>
# </tr>
# <tr class="lst50" data-song-no="37464459" id="lst50">
# <td><div class="wrap t_right"><input class="input_check" name="input_check" title="Bubble Gum 곡 선택" type="checkbox" value="37464459"/></div></td>
# <td><div class="wrap t_center"><span class="rank">9</span><span class="none">위</span></div></td>
# <!-- 차트순위 추가 -->
# <td><div class="wrap">
# <span class="rank_wrap" title="순위 동일">
# <span class="bullet_icons rank_static"><span class="none">순위 동일</span></span>
# <span class="none">0</span>
# </span>
# </div></td>
# <td><div class="wrap">
# <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('11475749');" title="How Sweet">
# <img alt="How Sweet - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="https://cdnimg.melon.co.kr/cm2/album/images/114/75/749/11475749_20240524105642_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
# <span class="bg_album_frame"></span>
# </a>
# </div></td>
# <td><div class="wrap">
# <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('37464459');" title="Bubble Gum 곡정보"><span class="none">곡정보</span></a>
# </div></td>
# <td><div class="wrap">
# <div class="wrap_song_info">
# <div class="ellipsis rank01"><span>
# <a href="javascript:melon.play.playSong('1000002721',37464459);" title="Bubble Gum 재생">Bubble Gum</a>
# </span></div><br/>
# <div class="ellipsis rank02">
# <a href="javascript:melon.link.goArtistDetail('3114174');" title="NewJeans - 페이지 이동">NewJeans</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('3114174');" title="NewJeans - 페이지 이동">NewJeans</a></span>
# </div>
# </div>
# </div></td>
# <td><div class="wrap">
# <div class="wrap_song_info">
# <div class="ellipsis rank03">
# <a href="javascript:melon.link.goAlbumDetail('11475749');" title="How Sweet - 페이지 이동">How Sweet</a>
# </div>
# </div>
# </div></td>
# <td><div class="wrap">
# <button class="button_etc like" data-song-menuid="1000002721" data-song-no="37464459" title="Bubble Gum 좋아요" type="button">
# <span class="odd_span">좋아요</span>
# <span class="cnt">
# <span class="none">총건수</span>
# 												0
# 											</span>
# </button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons play" onclick="melon.play.playSong('1000002721',37464459);" title="듣기" type="button"><span class="none">듣기</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons scrap" onclick="melon.play.addPlayList('37464459');" title="담기" type="button"><span class="none">담기</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons download" onclick="melon.buy.goBuyProduct('frm', '37464459', '3C0001', '','0', '1000002721');" title="다운로드" type="button"><span class="none">다운로드</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons video" onclick="melon.link.goMvDetail('1000002721', '37464459','song');" title="뮤직비디오" type="button"><span class="none">뮤직비디오</span></button>
# </div></td>
# </tr>
# <tr class="lst50" data-song-no="31927275" id="lst50">
# <td><div class="wrap t_right"><input class="input_check" name="input_check" title="한 페이지가 될 수 있게 곡 선택" type="checkbox" value="31927275"/></div></td>
# <td><div class="wrap t_center"><span class="rank">10</span><span class="none">위</span></div></td>
# <!-- 차트순위 추가 -->
# <td><div class="wrap">
# <span class="rank_wrap" title="순위 동일">
# <span class="bullet_icons rank_static"><span class="none">순위 동일</span></span>
# <span class="none">0</span>
# </span>
# </div></td>
# <td><div class="wrap">
# <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('10307346');" title="The Book of Us : Gravity">
# <img alt="The Book of Us : Gravity - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="https://cdnimg.melon.co.kr/cm/album/images/103/07/346/10307346_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
# <span class="bg_album_frame"></span>
# </a>
# </div></td>
# <td><div class="wrap">
# <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('31927275');" title="한 페이지가 될 수 있게 곡정보"><span class="none">곡정보</span></a>
# </div></td>
# <td><div class="wrap">
# <div class="wrap_song_info">
# <div class="ellipsis rank01"><span>
# <a href="javascript:melon.play.playSong('1000002721',31927275);" title="한 페이지가 될 수 있게 재생">한 페이지가 될 수 있게</a>
# </span></div><br/>
# <div class="ellipsis rank02">
# <a href="javascript:melon.link.goArtistDetail('894864');" title="DAY6 (데이식스) - 페이지 이동">DAY6 (데이식스)</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('894864');" title="DAY6 (데이식스) - 페이지 이동">DAY6 (데이식스)</a></span>
# </div>
# </div>
# </div></td>
# <td><div class="wrap">
# <div class="wrap_song_info">
# <div class="ellipsis rank03">
# <a href="javascript:melon.link.goAlbumDetail('10307346');" title="The Book of Us : Gravity - 페이지 이동">The Book of Us : Gravity</a>
# </div>
# </div>
# </div></td>
# <td><div class="wrap">
# <button class="button_etc like" data-song-menuid="1000002721" data-song-no="31927275" title="한 페이지가 될 수 있게 좋아요" type="button">
# <span class="odd_span">좋아요</span>
# <span class="cnt">
# <span class="none">총건수</span>
# 												0
# 											</span>
# </button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons play" onclick="melon.play.playSong('1000002721',31927275);" title="듣기" type="button"><span class="none">듣기</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons scrap" onclick="melon.play.addPlayList('31927275');" title="담기" type="button"><span class="none">담기</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons download" onclick="melon.buy.goBuyProduct('frm', '31927275', '3C0001', '','0', '1000002721');" title="다운로드" type="button"><span class="none">다운로드</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons video" onclick="melon.link.goMvDetail('1000002721', '31927275','song');" title="뮤직비디오" type="button"><span class="none">뮤직비디오</span></button>
# </div></td>
# </tr>
# <tr class="lst50" data-song-no="37524038" id="lst50">
# <td><div class="wrap t_right"><input class="input_check" name="input_check" title="Armageddon 곡 선택" type="checkbox" value="37524038"/></div></td>
# <td><div class="wrap t_center"><span class="rank">11</span><span class="none">위</span></div></td>
# <!-- 차트순위 추가 -->
# <td><div class="wrap">
# <span class="rank_wrap" title="순위 동일">
# <span class="bullet_icons rank_static"><span class="none">순위 동일</span></span>
# <span class="none">0</span>
# </span>
# </div></td>
# <td><div class="wrap">
# <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('11487023');" title="Armageddon - The 1st Album">
# <img alt="Armageddon - The 1st Album - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="https://cdnimg.melon.co.kr/cm2/album/images/114/87/023/11487023_20240527154018_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
# <span class="bg_album_frame"></span>
# </a>
# </div></td>
# <td><div class="wrap">
# <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('37524038');" title="Armageddon 곡정보"><span class="none">곡정보</span></a>
# </div></td>
# <td><div class="wrap">
# <div class="wrap_song_info">
# <div class="ellipsis rank01"><span>
# <a href="javascript:melon.play.playSong('1000002721',37524038);" title="Armageddon 재생">Armageddon</a>
# </span></div><br/>
# <div class="ellipsis rank02">
# <a href="javascript:melon.link.goArtistDetail('2899555');" title="aespa - 페이지 이동">aespa</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('2899555');" title="aespa - 페이지 이동">aespa</a></span>
# </div>
# </div>
# </div></td>
# <td><div class="wrap">
# <div class="wrap_song_info">
# <div class="ellipsis rank03">
# <a href="javascript:melon.link.goAlbumDetail('11487023');" title="Armageddon - The 1st Album - 페이지 이동">Armageddon - The 1st Album</a>
# </div>
# </div>
# </div></td>
# <td><div class="wrap">
# <button class="button_etc like" data-song-menuid="1000002721" data-song-no="37524038" title="Armageddon 좋아요" type="button">
# <span class="odd_span">좋아요</span>
# <span class="cnt">
# <span class="none">총건수</span>
# 												0
# 											</span>
# </button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons play" onclick="melon.play.playSong('1000002721',37524038);" title="듣기" type="button"><span class="none">듣기</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons scrap" onclick="melon.play.addPlayList('37524038');" title="담기" type="button"><span class="none">담기</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons download" onclick="melon.buy.goBuyProduct('frm', '37524038', '3C0001', '','0', '1000002721');" title="다운로드" type="button"><span class="none">다운로드</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons video" onclick="melon.link.goMvDetail('1000002721', '37524038','song');" title="뮤직비디오" type="button"><span class="none">뮤직비디오</span></button>
# </div></td>
# </tr>
# <tr class="lst50" data-song-no="37138469" id="lst50">
# <td><div class="wrap t_right"><input class="input_check" name="input_check" title="나는 아픈 건 딱 질색이니까 곡 선택" type="checkbox" value="37138469"/></div></td>
# <td><div class="wrap t_center"><span class="rank">12</span><span class="none">위</span></div></td>
# <!-- 차트순위 추가 -->
# <td><div class="wrap">
# <span class="rank_wrap" title="순위 동일">
# <span class="bullet_icons rank_static"><span class="none">순위 동일</span></span>
# <span class="none">0</span>
# </span>
# </div></td>
# <td><div class="wrap">
# <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('11402655');" title="2">
# <img alt="2 - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="https://cdnimg.melon.co.kr/cm2/album/images/114/02/655/11402655_20240129121016_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
# <span class="bg_album_frame"></span>
# </a>
# </div></td>
# <td><div class="wrap">
# <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('37138469');" title="나는 아픈 건 딱 질색이니까 곡정보"><span class="none">곡정보</span></a>
# </div></td>
# <td><div class="wrap">
# <div class="wrap_song_info">
# <div class="ellipsis rank01"><span>
# <a href="javascript:melon.play.playSong('1000002721',37138469);" title="나는 아픈 건 딱 질색이니까 재생">나는 아픈 건 딱 질색이니까</a>
# </span></div><br/>
# <div class="ellipsis rank02">
# <a href="javascript:melon.link.goArtistDetail('2137482');" title="(여자)아이들 - 페이지 이동">(여자)아이들</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('2137482');" title="(여자)아이들 - 페이지 이동">(여자)아이들</a></span>
# </div>
# </div>
# </div></td>
# <td><div class="wrap">
# <div class="wrap_song_info">
# <div class="ellipsis rank03">
# <a href="javascript:melon.link.goAlbumDetail('11402655');" title="2 - 페이지 이동">2</a>
# </div>
# </div>
# </div></td>
# <td><div class="wrap">
# <button class="button_etc like" data-song-menuid="1000002721" data-song-no="37138469" title="나는 아픈 건 딱 질색이니까 좋아요" type="button">
# <span class="odd_span">좋아요</span>
# <span class="cnt">
# <span class="none">총건수</span>
# 												0
# 											</span>
# </button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons play" onclick="melon.play.playSong('1000002721',37138469);" title="듣기" type="button"><span class="none">듣기</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons scrap" onclick="melon.play.addPlayList('37138469');" title="담기" type="button"><span class="none">담기</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons download" onclick="melon.buy.goBuyProduct('frm', '37138469', '3C0001', '','0', '1000002721');" title="다운로드" type="button"><span class="none">다운로드</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons video disabled" disabled="disabled" onclick="melon.link.goMvDetail('1000002721', '37138469','song');" title="뮤직비디오" type="button"><span class="none">뮤직비디오</span></button>
# </div></td>
# </tr>
# <tr class="lst50" data-song-no="37463572" id="lst50">
# <td><div class="wrap t_right"><input class="input_check" name="input_check" title="해야 (HEYA) 곡 선택" type="checkbox" value="37463572"/></div></td>
# <td><div class="wrap t_center"><span class="rank">13</span><span class="none">위</span></div></td>
# <!-- 차트순위 추가 -->
# <td><div class="wrap">
# <span class="rank_wrap" title="1단계 상승">
# <span class="bullet_icons rank_up"><span class="none">단계 상승</span></span>
# <span class="up">1</span>
# </span>
# </div></td>
# <td><div class="wrap">
# <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('11475530');" title="IVE SWITCH">
# <img alt="IVE SWITCH - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="https://cdnimg.melon.co.kr/cm2/album/images/114/75/530/11475530_20240430093854_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
# <span class="bg_album_frame"></span>
# </a>
# </div></td>
# <td><div class="wrap">
# <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('37463572');" title="해야 (HEYA) 곡정보"><span class="none">곡정보</span></a>
# </div></td>
# <td><div class="wrap">
# <div class="wrap_song_info">
# <div class="ellipsis rank01"><span>
# <a href="javascript:melon.play.playSong('1000002721',37463572);" title="해야 (HEYA) 재생">해야 (HEYA)</a>
# </span></div><br/>
# <div class="ellipsis rank02">
# <a href="javascript:melon.link.goArtistDetail('3055146');" title="IVE (아이브) - 페이지 이동">IVE (아이브)</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('3055146');" title="IVE (아이브) - 페이지 이동">IVE (아이브)</a></span>
# </div>
# </div>
# </div></td>
# <td><div class="wrap">
# <div class="wrap_song_info">
# <div class="ellipsis rank03">
# <a href="javascript:melon.link.goAlbumDetail('11475530');" title="IVE SWITCH - 페이지 이동">IVE SWITCH</a>
# </div>
# </div>
# </div></td>
# <td><div class="wrap">
# <button class="button_etc like" data-song-menuid="1000002721" data-song-no="37463572" title="해야 (HEYA) 좋아요" type="button">
# <span class="odd_span">좋아요</span>
# <span class="cnt">
# <span class="none">총건수</span>
# 												0
# 											</span>
# </button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons play" onclick="melon.play.playSong('1000002721',37463572);" title="듣기" type="button"><span class="none">듣기</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons scrap" onclick="melon.play.addPlayList('37463572');" title="담기" type="button"><span class="none">담기</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons download" onclick="melon.buy.goBuyProduct('frm', '37463572', '3C0001', '','0', '1000002721');" title="다운로드" type="button"><span class="none">다운로드</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons video" onclick="melon.link.goMvDetail('1000002721', '37463572','song');" title="뮤직비디오" type="button"><span class="none">뮤직비디오</span></button>
# </div></td>
# </tr>
# <tr class="lst50" data-song-no="37347911" id="lst50">
# <td><div class="wrap t_right"><input class="input_check" name="input_check" title="Magnetic 곡 선택" type="checkbox" value="37347911"/></div></td>
# <td><div class="wrap t_center"><span class="rank">14</span><span class="none">위</span></div></td>
# <!-- 차트순위 추가 -->
# <td><div class="wrap">
# <span class="rank_wrap" title="1단계 하락">
# <span class="bullet_icons rank_down"><span class="none">단계 하락</span></span>
# <span class="down">1</span>
# </span>
# </div></td>
# <td><div class="wrap">
# <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('11450069');" title="SUPER REAL ME">
# <img alt="SUPER REAL ME - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="https://cdnimg.melon.co.kr/cm2/album/images/114/50/069/11450069_20240325110702_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
# <span class="bg_album_frame"></span>
# </a>
# </div></td>
# <td><div class="wrap">
# <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('37347911');" title="Magnetic 곡정보"><span class="none">곡정보</span></a>
# </div></td>
# <td><div class="wrap">
# <div class="wrap_song_info">
# <div class="ellipsis rank01"><span>
# <a href="javascript:melon.play.playSong('1000002721',37347911);" title="Magnetic 재생">Magnetic</a>
# </span></div><br/>
# <div class="ellipsis rank02">
# <a href="javascript:melon.link.goArtistDetail('3743525');" title="아일릿(ILLIT) - 페이지 이동">아일릿(ILLIT)</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('3743525');" title="아일릿(ILLIT) - 페이지 이동">아일릿(ILLIT)</a></span>
# </div>
# </div>
# </div></td>
# <td><div class="wrap">
# <div class="wrap_song_info">
# <div class="ellipsis rank03">
# <a href="javascript:melon.link.goAlbumDetail('11450069');" title="SUPER REAL ME - 페이지 이동">SUPER REAL ME</a>
# </div>
# </div>
# </div></td>
# <td><div class="wrap">
# <button class="button_etc like" data-song-menuid="1000002721" data-song-no="37347911" title="Magnetic 좋아요" type="button">
# <span class="odd_span">좋아요</span>
# <span class="cnt">
# <span class="none">총건수</span>
# 												0
# 											</span>
# </button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons play" onclick="melon.play.playSong('1000002721',37347911);" title="듣기" type="button"><span class="none">듣기</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons scrap" onclick="melon.play.addPlayList('37347911');" title="담기" type="button"><span class="none">담기</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons download" onclick="melon.buy.goBuyProduct('frm', '37347911', '3C0001', '','0', '1000002721');" title="다운로드" type="button"><span class="none">다운로드</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons video" onclick="melon.link.goMvDetail('1000002721', '37347911','song');" title="뮤직비디오" type="button"><span class="none">뮤직비디오</span></button>
# </div></td>
# </tr>
# <tr class="lst50" data-song-no="37460832" id="lst50">
# <td><div class="wrap t_right"><input class="input_check" name="input_check" title="SPOT! (feat. JENNIE) 곡 선택" type="checkbox" value="37460832"/></div></td>
# <td><div class="wrap t_center"><span class="rank">15</span><span class="none">위</span></div></td>
# <!-- 차트순위 추가 -->
# <td><div class="wrap">
# <span class="rank_wrap" title="순위 동일">
# <span class="bullet_icons rank_static"><span class="none">순위 동일</span></span>
# <span class="none">0</span>
# </span>
# </div></td>
# <td><div class="wrap">
# <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('11474894');" title="SPOT!">
# <img alt="SPOT! - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="https://cdnimg.melon.co.kr/cm2/album/images/114/74/894/11474894_20240426103349_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
# <span class="bg_album_frame"></span>
# </a>
# </div></td>
# <td><div class="wrap">
# <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('37460832');" title="SPOT! (feat. JENNIE) 곡정보"><span class="none">곡정보</span></a>
# </div></td>
# <td><div class="wrap">
# <div class="wrap_song_info">
# <div class="ellipsis rank01"><span>
# <a href="javascript:melon.play.playSong('1000002721',37460832);" title="SPOT! (feat. JENNIE) 재생">SPOT! (feat. JENNIE)</a>
# </span></div><br/>
# <div class="ellipsis rank02">
# <a href="javascript:melon.link.goArtistDetail('602056');" title="지코 (ZICO) - 페이지 이동">지코 (ZICO)</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('602056');" title="지코 (ZICO) - 페이지 이동">지코 (ZICO)</a></span>
# </div>
# </div>
# </div></td>
# <td><div class="wrap">
# <div class="wrap_song_info">
# <div class="ellipsis rank03">
# <a href="javascript:melon.link.goAlbumDetail('11474894');" title="SPOT! - 페이지 이동">SPOT!</a>
# </div>
# </div>
# </div></td>
# <td><div class="wrap">
# <button class="button_etc like" data-song-menuid="1000002721" data-song-no="37460832" title="SPOT! (feat. JENNIE) 좋아요" type="button">
# <span class="odd_span">좋아요</span>
# <span class="cnt">
# <span class="none">총건수</span>
# 												0
# 											</span>
# </button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons play" onclick="melon.play.playSong('1000002721',37460832);" title="듣기" type="button"><span class="none">듣기</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons scrap" onclick="melon.play.addPlayList('37460832');" title="담기" type="button"><span class="none">담기</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons download" onclick="melon.buy.goBuyProduct('frm', '37460832', '3C0001', '','0', '1000002721');" title="다운로드" type="button"><span class="none">다운로드</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons video" onclick="melon.link.goMvDetail('1000002721', '37460832','song');" title="뮤직비디오" type="button"><span class="none">뮤직비디오</span></button>
# </div></td>
# </tr>
# <tr class="lst50" data-song-no="37140709" id="lst50">
# <td><div class="wrap t_right"><input class="input_check" name="input_check" title="첫 만남은 계획대로 되지 않아 곡 선택" type="checkbox" value="37140709"/></div></td>
# <td><div class="wrap t_center"><span class="rank">16</span><span class="none">위</span></div></td>
# <!-- 차트순위 추가 -->
# <td><div class="wrap">
# <span class="rank_wrap" title="1단계 상승">
# <span class="bullet_icons rank_up"><span class="none">단계 상승</span></span>
# <span class="up">1</span>
# </span>
# </div></td>
# <td><div class="wrap">
# <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('11391902');" title="TWS 1st Mini Album ‘Sparkling Blue’">
# <img alt="TWS 1st Mini Album ‘Sparkling Blue’ - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="https://cdnimg.melon.co.kr/cm2/album/images/113/91/902/11391902_20240122132041_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
# <span class="bg_album_frame"></span>
# </a>
# </div></td>
# <td><div class="wrap">
# <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('37140709');" title="첫 만남은 계획대로 되지 않아 곡정보"><span class="none">곡정보</span></a>
# </div></td>
# <td><div class="wrap">
# <div class="wrap_song_info">
# <div class="ellipsis rank01"><span>
# <a href="javascript:melon.play.playSong('1000002721',37140709);" title="첫 만남은 계획대로 되지 않아 재생">첫 만남은 계획대로 되지 않아</a>
# </span></div><br/>
# <div class="ellipsis rank02">
# <a href="javascript:melon.link.goArtistDetail('3679688');" title="TWS (투어스) - 페이지 이동">TWS (투어스)</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('3679688');" title="TWS (투어스) - 페이지 이동">TWS (투어스)</a></span>
# </div>
# </div>
# </div></td>
# <td><div class="wrap">
# <div class="wrap_song_info">
# <div class="ellipsis rank03">
# <a href="javascript:melon.link.goAlbumDetail('11391902');" title="TWS 1st Mini Album ‘Sparkling Blue’ - 페이지 이동">TWS 1st Mini Album ‘Sparkling Blue’</a>
# </div>
# </div>
# </div></td>
# <td><div class="wrap">
# <button class="button_etc like" data-song-menuid="1000002721" data-song-no="37140709" title="첫 만남은 계획대로 되지 않아 좋아요" type="button">
# <span class="odd_span">좋아요</span>
# <span class="cnt">
# <span class="none">총건수</span>
# 												0
# 											</span>
# </button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons play" onclick="melon.play.playSong('1000002721',37140709);" title="듣기" type="button"><span class="none">듣기</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons scrap" onclick="melon.play.addPlayList('37140709');" title="담기" type="button"><span class="none">담기</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons download" onclick="melon.buy.goBuyProduct('frm', '37140709', '3C0001', '','0', '1000002721');" title="다운로드" type="button"><span class="none">다운로드</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons video" onclick="melon.link.goMvDetail('1000002721', '37140709','song');" title="뮤직비디오" type="button"><span class="none">뮤직비디오</span></button>
# </div></td>
# </tr>
# <tr class="lst50" data-song-no="37323943" id="lst50">
# <td><div class="wrap t_right"><input class="input_check" name="input_check" title="Welcome to the Show 곡 선택" type="checkbox" value="37323943"/></div></td>
# <td><div class="wrap t_center"><span class="rank">17</span><span class="none">위</span></div></td>
# <!-- 차트순위 추가 -->
# ...
# </div>
# </div>
# </div></td>
# <td><div class="wrap">
# <div class="wrap_song_info">
# <div class="ellipsis rank03">
# <a href="javascript:melon.link.goAlbumDetail('11487566');" title="선재 업고 튀어 OST Part 8 - 페이지 이동">선재 업고 튀어 OST Part 8</a>
# </div>
# </div>
# </div></td>
# <td><div class="wrap">
# <button class="button_etc like" data-song-menuid="1000002721" data-song-no="37526257" title="봄눈 좋아요" type="button">
# <span class="odd_span">좋아요</span>
# <span class="cnt">
# <span class="none">총건수</span>
# 												0
# 											</span>
# </button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons play" onclick="melon.play.playSong('1000002721',37526257);" title="듣기" type="button"><span class="none">듣기</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons scrap" onclick="melon.play.addPlayList('37526257');" title="담기" type="button"><span class="none">담기</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons download" onclick="melon.buy.goBuyProduct('frm', '37526257', '3C0001', '','0', '1000002721');" title="다운로드" type="button"><span class="none">다운로드</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons video disabled" disabled="disabled" onclick="melon.link.goMvDetail('1000002721', '37526257','song');" title="뮤직비디오" type="button"><span class="none">뮤직비디오</span></button>
# </div></td>
# </tr>
# <tr class="lst100" data-song-no="37347913" id="lst100">
# <td><div class="wrap t_right"><input class="input_check" name="input_check" title="Lucky Girl Syndrome 곡 선택" type="checkbox" value="37347913"/></div></td>
# <td><div class="wrap t_center"><span class="rank">97</span><span class="none">위</span></div></td>
# <!-- 차트순위 추가 -->
# <td><div class="wrap">
# <span class="rank_wrap" title="순위 동일">
# <span class="bullet_icons rank_static"><span class="none">순위 동일</span></span>
# <span class="none">0</span>
# </span>
# </div></td>
# <td><div class="wrap">
# <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('11450069');" title="SUPER REAL ME">
# <img alt="SUPER REAL ME - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="https://cdnimg.melon.co.kr/cm2/album/images/114/50/069/11450069_20240325110702_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
# <span class="bg_album_frame"></span>
# </a>
# </div></td>
# <td><div class="wrap">
# <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('37347913');" title="Lucky Girl Syndrome 곡정보"><span class="none">곡정보</span></a>
# </div></td>
# <td><div class="wrap">
# <div class="wrap_song_info">
# <div class="ellipsis rank01"><span>
# <a href="javascript:melon.play.playSong('1000002721',37347913);" title="Lucky Girl Syndrome 재생">Lucky Girl Syndrome</a>
# </span></div><br/>
# <div class="ellipsis rank02">
# <a href="javascript:melon.link.goArtistDetail('3743525');" title="아일릿(ILLIT) - 페이지 이동">아일릿(ILLIT)</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('3743525');" title="아일릿(ILLIT) - 페이지 이동">아일릿(ILLIT)</a></span>
# </div>
# </div>
# </div></td>
# <td><div class="wrap">
# <div class="wrap_song_info">
# <div class="ellipsis rank03">
# <a href="javascript:melon.link.goAlbumDetail('11450069');" title="SUPER REAL ME - 페이지 이동">SUPER REAL ME</a>
# </div>
# </div>
# </div></td>
# <td><div class="wrap">
# <button class="button_etc like" data-song-menuid="1000002721" data-song-no="37347913" title="Lucky Girl Syndrome 좋아요" type="button">
# <span class="odd_span">좋아요</span>
# <span class="cnt">
# <span class="none">총건수</span>
# 												0
# 											</span>
# </button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons play" onclick="melon.play.playSong('1000002721',37347913);" title="듣기" type="button"><span class="none">듣기</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons scrap" onclick="melon.play.addPlayList('37347913');" title="담기" type="button"><span class="none">담기</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons download" onclick="melon.buy.goBuyProduct('frm', '37347913', '3C0001', '','0', '1000002721');" title="다운로드" type="button"><span class="none">다운로드</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons video" onclick="melon.link.goMvDetail('1000002721', '37347913','song');" title="뮤직비디오" type="button"><span class="none">뮤직비디오</span></button>
# </div></td>
# </tr>
# <tr class="lst100" data-song-no="37431365" id="lst100">
# <td><div class="wrap t_right"><input class="input_check" name="input_check" title="Impossible 곡 선택" type="checkbox" value="37431365"/></div></td>
# <td><div class="wrap t_center"><span class="rank">98</span><span class="none">위</span></div></td>
# <!-- 차트순위 추가 -->
# <td><div class="wrap">
# <span class="rank_wrap" title="순위 동일">
# <span class="bullet_icons rank_static"><span class="none">순위 동일</span></span>
# <span class="none">0</span>
# </span>
# </div></td>
# <td><div class="wrap">
# <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('11456179');" title="RIIZING - The 1st Mini Album">
# <img alt="RIIZING - The 1st Mini Album - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="https://cdnimg.melon.co.kr/cm2/album/images/114/56/179/11456179_20240617152303_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
# <span class="bg_album_frame"></span>
# </a>
# </div></td>
# <td><div class="wrap">
# <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('37431365');" title="Impossible 곡정보"><span class="none">곡정보</span></a>
# </div></td>
# <td><div class="wrap">
# <div class="wrap_song_info">
# <div class="ellipsis rank01"><span>
# <a href="javascript:melon.play.playSong('1000002721',37431365);" title="Impossible 재생">Impossible</a>
# </span></div><br/>
# <div class="ellipsis rank02">
# <a href="javascript:melon.link.goArtistDetail('3478478');" title="RIIZE - 페이지 이동">RIIZE</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('3478478');" title="RIIZE - 페이지 이동">RIIZE</a></span>
# </div>
# </div>
# </div></td>
# <td><div class="wrap">
# <div class="wrap_song_info">
# <div class="ellipsis rank03">
# <a href="javascript:melon.link.goAlbumDetail('11456179');" title="RIIZING - The 1st Mini Album - 페이지 이동">RIIZING - The 1st Mini Album</a>
# </div>
# </div>
# </div></td>
# <td><div class="wrap">
# <button class="button_etc like" data-song-menuid="1000002721" data-song-no="37431365" title="Impossible 좋아요" type="button">
# <span class="odd_span">좋아요</span>
# <span class="cnt">
# <span class="none">총건수</span>
# 												0
# 											</span>
# </button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons play" onclick="melon.play.playSong('1000002721',37431365);" title="듣기" type="button"><span class="none">듣기</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons scrap" onclick="melon.play.addPlayList('37431365');" title="담기" type="button"><span class="none">담기</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons download" onclick="melon.buy.goBuyProduct('frm', '37431365', '3C0001', '','0', '1000002721');" title="다운로드" type="button"><span class="none">다운로드</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons video" onclick="melon.link.goMvDetail('1000002721', '37431365','song');" title="뮤직비디오" type="button"><span class="none">뮤직비디오</span></button>
# </div></td>
# </tr>
# <tr class="lst100" data-song-no="37225604" id="lst100">
# <td><div class="wrap t_right"><input class="input_check" name="input_check" title="EASY 곡 선택" type="checkbox" value="37225604"/></div></td>
# <td><div class="wrap t_center"><span class="rank">99</span><span class="none">위</span></div></td>
# <!-- 차트순위 추가 -->
# <td><div class="wrap">
# <span class="rank_wrap" title="순위 동일">
# <span class="bullet_icons rank_static"><span class="none">순위 동일</span></span>
# <span class="none">0</span>
# </span>
# </div></td>
# <td><div class="wrap">
# <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('11407156');" title="EASY">
# <img alt="EASY - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="https://cdnimg.melon.co.kr/cm2/album/images/114/07/156/11407156_20240219142535_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
# <span class="bg_album_frame"></span>
# </a>
# </div></td>
# <td><div class="wrap">
# <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('37225604');" title="EASY 곡정보"><span class="none">곡정보</span></a>
# </div></td>
# <td><div class="wrap">
# <div class="wrap_song_info">
# <div class="ellipsis rank01"><span>
# <a href="javascript:melon.play.playSong('1000002721',37225604);" title="EASY 재생">EASY</a>
# </span></div><br/>
# <div class="ellipsis rank02">
# <a href="javascript:melon.link.goArtistDetail('3092950');" title="LE SSERAFIM (르세라핌) - 페이지 이동">LE SSERAFIM (르세라핌)</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('3092950');" title="LE SSERAFIM (르세라핌) - 페이지 이동">LE SSERAFIM (르세라핌)</a></span>
# </div>
# </div>
# </div></td>
# <td><div class="wrap">
# <div class="wrap_song_info">
# <div class="ellipsis rank03">
# <a href="javascript:melon.link.goAlbumDetail('11407156');" title="EASY - 페이지 이동">EASY</a>
# </div>
# </div>
# </div></td>
# <td><div class="wrap">
# <button class="button_etc like" data-song-menuid="1000002721" data-song-no="37225604" title="EASY 좋아요" type="button">
# <span class="odd_span">좋아요</span>
# <span class="cnt">
# <span class="none">총건수</span>
# 												0
# 											</span>
# </button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons play" onclick="melon.play.playSong('1000002721',37225604);" title="듣기" type="button"><span class="none">듣기</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons scrap" onclick="melon.play.addPlayList('37225604');" title="담기" type="button"><span class="none">담기</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons download" onclick="melon.buy.goBuyProduct('frm', '37225604', '3C0001', '','0', '1000002721');" title="다운로드" type="button"><span class="none">다운로드</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons video" onclick="melon.link.goMvDetail('1000002721', '37225604','song');" title="뮤직비디오" type="button"><span class="none">뮤직비디오</span></button>
# </div></td>
# </tr>
# <tr class="lst100" data-song-no="37378932" id="lst100">
# <td><div class="wrap t_right"><input class="input_check" name="input_check" title="Siren 곡 선택" type="checkbox" value="37378932"/></div></td>
# <td><div class="wrap t_center"><span class="rank">100</span><span class="none">위</span></div></td>
# <!-- 차트순위 추가 -->
# <td><div class="wrap">
# <span class="rank_wrap" title="순위 동일">
# <span class="bullet_icons rank_static"><span class="none">순위 동일</span></span>
# <span class="none">0</span>
# </span>
# </div></td>
# <td><div class="wrap">
# <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('11456179');" title="RIIZING - The 1st Mini Album">
# <img alt="RIIZING - The 1st Mini Album - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="https://cdnimg.melon.co.kr/cm2/album/images/114/56/179/11456179_20240617152303_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
# <span class="bg_album_frame"></span>
# </a>
# </div></td>
# <td><div class="wrap">
# <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('37378932');" title="Siren 곡정보"><span class="none">곡정보</span></a>
# </div></td>
# <td><div class="wrap">
# <div class="wrap_song_info">
# <div class="ellipsis rank01"><span>
# <a href="javascript:melon.play.playSong('1000002721',37378932);" title="Siren 재생">Siren</a>
# </span></div><br/>
# <div class="ellipsis rank02">
# <a href="javascript:melon.link.goArtistDetail('3478478');" title="RIIZE - 페이지 이동">RIIZE</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('3478478');" title="RIIZE - 페이지 이동">RIIZE</a></span>
# </div>
# </div>
# </div></td>
# <td><div class="wrap">
# <div class="wrap_song_info">
# <div class="ellipsis rank03">
# <a href="javascript:melon.link.goAlbumDetail('11456179');" title="RIIZING - The 1st Mini Album - 페이지 이동">RIIZING - The 1st Mini Album</a>
# </div>
# </div>
# </div></td>
# <td><div class="wrap">
# <button class="button_etc like" data-song-menuid="1000002721" data-song-no="37378932" title="Siren 좋아요" type="button">
# <span class="odd_span">좋아요</span>
# <span class="cnt">
# <span class="none">총건수</span>
# 												0
# 											</span>
# </button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons play" onclick="melon.play.playSong('1000002721',37378932);" title="듣기" type="button"><span class="none">듣기</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons scrap" onclick="melon.play.addPlayList('37378932');" title="담기" type="button"><span class="none">담기</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons download" onclick="melon.buy.goBuyProduct('frm', '37378932', '3C0001', '','0', '1000002721');" title="다운로드" type="button"><span class="none">다운로드</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons video" onclick="melon.link.goMvDetail('1000002721', '37378932','song');" title="뮤직비디오" type="button"><span class="none">뮤직비디오</span></button>
# </div></td>
# </tr>
#                            title              artist  \
# 0                      Supernova               aespa
# 1                      How Sweet            NewJeans
# 2   Small girl (feat. 도경수(D.O.))                 이영지
# 3                   클락션 (Klaxon)             (여자)아이들
# 4                   Supernatural            NewJeans
# ..                           ...                 ...
# 95                            봄눈                10CM
# 96           Lucky Girl Syndrome          아일릿(ILLIT)
# 97                    Impossible               RIIZE
# 98                          EASY  LE SSERAFIM (르세라핌)
# 99                         Siren               RIIZE
#
#                            album release_date       genre  \
# 0     Armageddon - The 1st Album   2024.05.13          댄스
# 1                      How Sweet   2024.05.24          댄스
# 2                     16 Fantasy   2024.06.21        랩/힙합
# 3                         I SWAY   2024.07.08          댄스
# 4                   Supernatural   2024.06.21       J-POP
# ..                           ...          ...         ...
# 95           선재 업고 튀어 OST Part 8   2024.05.14  발라드, 국내드라마
# 96                 SUPER REAL ME   2024.03.25          댄스
# 97  RIIZING - The 1st Mini Album   2024.04.18          댄스
# 98                          EASY   2024.02.19        랩/힙합
# 99  RIIZING - The 1st Mini Album   2024.04.03          댄스
#
#                            likes  \
# 0   총건수\n\t\t\t\t\t\t\t\t\t\t\t0
# 1   총건수\n\t\t\t\t\t\t\t\t\t\t\t0
# 2   총건수\n\t\t\t\t\t\t\t\t\t\t\t0
# 3   총건수\n\t\t\t\t\t\t\t\t\t\t\t0
# 4   총건수\n\t\t\t\t\t\t\t\t\t\t\t0
# ..                           ...
# 95  총건수\n\t\t\t\t\t\t\t\t\t\t\t0
# 96  총건수\n\t\t\t\t\t\t\t\t\t\t\t0
# 97  총건수\n\t\t\t\t\t\t\t\t\t\t\t0
# 98  총건수\n\t\t\t\t\t\t\t\t\t\t\t0
# 99  총건수\n\t\t\t\t\t\t\t\t\t\t\t0
#
#                                                lyrics
# 0   I’m like some kind of SupernovaWatch outLook a...
# 1   All I know is now알게 됐어 나 (I know)그동안 맨날Always ...
# 2   If I got a two small cheeksand a bright pink l...
# 3   좀 미친 소리 같지만 난 네게 반했어(어어우워 어어우워)자꾸 눈으로 욕 하지마 더 ...
# 4   Stormy nightCloudy skyIn a moment you and IOne...
# ..                                                ...
# 95  가려진 오랜 시간이우리를 다시 불러와어느 곳에 있어도그 끝은 항상 너인걸Cause ...
# 96  완벽한 날씨딱 맞는 playlist오늘의 selfieI say I’m lucky 세...
# 97  Gimme that beatGot me flyin’in my dreams right...
# 98  다친대도 길을 걸어 kiss me쉽지 않음 내가 쉽게 easyStage 위엔 불이 ...
# 99  Beat droppin’ low feelin’ up뒤섞여 봐 완전히 새로운 Flow...
#
# [100 rows x 7 columns]
